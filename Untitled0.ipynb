# %% [markdown]
# <a href="https://colab.research.google.com/github/omisssss/automated-recipe-selector-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

# %%
import pandas as pd
df=pd.read_csv('/content/titanic.csv')
df
# Out:
#      Class     Sex    Age Survived
# 0      3rd    Male  Child       No
# 1      3rd    Male  Child       No
# 2      3rd    Male  Child       No
# 3      3rd    Male  Child       No
# 4      3rd    Male  Child       No
# ...    ...     ...    ...      ...
# 2196  Crew  Female  Adult      Yes
# 2197  Crew  Female  Adult      Yes
# 2198  Crew  Female  Adult      Yes
# 2199  Crew  Female  Adult      Yes
# 2200  Crew  Female  Adult      Yes
#
# [2201 rows x 4 columns]

# %%
count=df['Class'].value_counts() #1st
print(count)
# Out:
# Crew    885
# 3rd     706
# 1st     325
# 2nd     285
# Name: Class, dtype: int64

# %%
def convert_gender(x): #2nd
  if(x=="Male"):
    ret ='1'
  else: ret='0'
  return ret
df['Sex']=df.Sex.apply(convert_gender)
df
# Out:
#      Class Sex    Age Survived
# 0      3rd   1  Child       No
# 1      3rd   1  Child       No
# 2      3rd   1  Child       No
# 3      3rd   1  Child       No
# 4      3rd   1  Child       No
# ...    ...  ..    ...      ...
# 2196  Crew   0  Adult      Yes
# 2197  Crew   0  Adult      Yes
# 2198  Crew   0  Adult      Yes
# 2199  Crew   0  Adult      Yes
# 2200  Crew   0  Adult      Yes
#
# [2201 rows x 4 columns]

# %%
df
# Out:
#      Class Sex    Age Survived
# 0      3rd   1  Child       No
# 1      3rd   1  Child       No
# 2      3rd   1  Child       No
# 3      3rd   1  Child       No
# 4      3rd   1  Child       No
# ...    ...  ..    ...      ...
# 2196  Crew   0  Adult      Yes
# 2197  Crew   0  Adult      Yes
# 2198  Crew   0  Adult      Yes
# 2199  Crew   0  Adult      Yes
# 2200  Crew   0  Adult      Yes
#
# [2201 rows x 4 columns]

# %%
dfx=df.groupby(['Age','Survived']).count()
dfx
# Out:
#                 Class   Sex
# Age   Survived
# Adult No         1438  1438
#       Yes         654   654
# Child No           52    52
#       Yes          57    57

# %%
df[df['Survived']=='Yes'].count()
df[df['Survived']=='No'].count()
# Out:
# Class       1490
# Sex         1490
# Age         1490
# Survived    1490
# dtype: int64

# %%
def Survived_rate(): #3rd
  a=df[df['Survived']=='Yes'].shape[0]

  b=df[df['Survived']=='No'].shape[0]

  if (a>b):
    print("the count Yes is more")
  else:
    print("the count of No is more")
  
Survived_rate()
# Out:
# the count of No is more

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
def Adultchild (): #4th
  a=df[df['Age']=='Adult'].shape[0]

  b=df[df['Age']=='Child'].shape[0]

  if(a>b):
    print("count of age adult is more")
  else:
    print("count of age child is more")

Adultchild()
# Out:
# count of age adult is more

# %%
mask1=df['Class']=='1st' #5
mask2=df['Class']=='2nd'
mask3=df['Class']=='3rd'
mask0=df['Survived']=='yes'

c1=df[mask0 & mask1].shape[0]
c2=df[mask0 & mask2].shape[0]
c3=df[mask0 & mask1].shape[0]

def class_Survived_less_Count(c1,c2,c3):
    if(c1<c2 and c1<c3):
       print("class 1st has less")
    elif(c2<c1 and c2<c3 ):
       print("class second has less")
    else:
        print("3rd class is less")

class_Survived_less_Count(c1,c2,c3)
# Out:
# 3rd class is less
